# %%
import pymysql 
from sqlalchemy import create_engine

# %%
engine= create_engine("mysql+pymysql://root:yourpassword@localhost/Project1")

# %%
engine
# Out:
# Engine(mysql+pymysql://yourpassword@localhost/Project1)

# %%
import pandas as pd

# %%
table1=pd.read_sql_query('SELECT * FROM Offres',engine)

# %%
table1
# Out:
#              Famille de métiers Agricultures et animaux  \
# 0                        Ain 01                     800
# 1                      Aisne 02                   1 040
# 2                     Allier 03                     270
# 3    Alpes-de-Haute-Provence 04                     250
# 4            Alpes-Maritimes 06                   1 040
# ..                          ...                     ...
# 96                    Vienne 86                     830
# 97                    Vosges 88                     390
# 98                     Yonne 89                     480
# 99                  Yvelines 78                   1 300
# 100                 Non précisé                   2 090
#
#      ARTS ET FACONNAGE D'OUVRAGES D'ART BANQUE, ASSURANCE, IMMOBILIER  \
# 0                                   120                         1 470
# 1                                    30                           810
# 2                                   110                           590
# ...

# %%
table1.columns[0]
# Out:
# 'Famille de métiers'

# %%
df = table1.melt(id_vars=['Famille de métiers'])

# %%
df['trimestre'] = 'Q1-2020'

# %%
df
# Out:
#               Famille de métiers                 variable      value trimestre
# 0                         Ain 01  Agricultures et animaux        800   Q1-2020
# 1                       Aisne 02  Agricultures et animaux      1 040   Q1-2020
# 2                      Allier 03  Agricultures et animaux        270   Q1-2020
# 3     Alpes-de-Haute-Provence 04  Agricultures et animaux        250   Q1-2020
# 4             Alpes-Maritimes 06  Agricultures et animaux      1 040   Q1-2020
# ...                          ...                      ...        ...       ...
# 1510                   Vienne 86                    TOTAL   34 520\r   Q1-2020
# 1511                   Vosges 88                    TOTAL   23 600\r   Q1-2020
# 1512                    Yonne 89                    TOTAL   24 480\r   Q1-2020
# 1513                 Yvelines 78                    TOTAL  116 950\r   Q1-2020
# 1514                 Non précisé                    TOTAL  220 310\r   Q1-2020
#
# [1515 rows x 4 columns]

# %%
df2 = df.copy()

# %%
df2['trimestre'] = 'Q2-2020'

# %%
df2
# Out:
#               Famille de métiers                 variable      value trimestre
# 0                         Ain 01  Agricultures et animaux        800   Q2-2020
# 1                       Aisne 02  Agricultures et animaux      1 040   Q2-2020
# 2                      Allier 03  Agricultures et animaux        270   Q2-2020
# 3     Alpes-de-Haute-Provence 04  Agricultures et animaux        250   Q2-2020
# 4             Alpes-Maritimes 06  Agricultures et animaux      1 040   Q2-2020
# ...                          ...                      ...        ...       ...
# 1510                   Vienne 86                    TOTAL   34 520\r   Q2-2020
# 1511                   Vosges 88                    TOTAL   23 600\r   Q2-2020
# 1512                    Yonne 89                    TOTAL   24 480\r   Q2-2020
# 1513                 Yvelines 78                    TOTAL  116 950\r   Q2-2020
# 1514                 Non précisé                    TOTAL  220 310\r   Q2-2020
#
# [1515 rows x 4 columns]

# %%
pd.concat([df, df2], axis=0)
# Out:
#               Famille de métiers                 variable      value trimestre
# 0                         Ain 01  Agricultures et animaux        800   Q1-2020
# 1                       Aisne 02  Agricultures et animaux      1 040   Q1-2020
# 2                      Allier 03  Agricultures et animaux        270   Q1-2020
# 3     Alpes-de-Haute-Provence 04  Agricultures et animaux        250   Q1-2020
# 4             Alpes-Maritimes 06  Agricultures et animaux      1 040   Q1-2020
# ...                          ...                      ...        ...       ...
# 1510                   Vienne 86                    TOTAL   34 520\r   Q2-2020
# 1511                   Vosges 88                    TOTAL   23 600\r   Q2-2020
# 1512                    Yonne 89                    TOTAL   24 480\r   Q2-2020
# 1513                 Yvelines 78                    TOTAL  116 950\r   Q2-2020
# 1514                 Non précisé                    TOTAL  220 310\r   Q2-2020
#
# [3030 rows x 4 columns]
