# %%
import pymysql 
from sqlalchemy import create_engine

# %%
engine= create_engine("mysql+pymysql://root:yourpassword@localhost/Ironhack")

# %%
import pandas as pd

# %%
table1 = pd.read_sql('select Date, Départements, cas_confirmes,deces,reanimation,hospitalises from Cas_covid',engine)

# %%
table2=pd.read_sql('select*from Offres', engine)

# %%
table3 = pd.read_sql('select Départements,cas_confirmes,deces,reanimation,hospitalises, Date from Cas_covid left join Offres on trimestre = Date',engine)

# %%
table3
# Out:
#                 Départements cas_confirmes    deces reanimation hospitalises  \
# 0                        Ain         943.0     67.0        88.0        550.0
# 1                      Aisne         436.0    778.0       376.0       1384.0
# 2                     Allier         188.0     38.0        31.0        244.0
# 3            Alpes-Maritimes        1096.0    145.0       221.0       1040.0
# 4    Alpes-de-Haute-Provence          90.0      3.0        20.0        116.0
# ..                       ...           ...      ...         ...          ...
# 702                   Vendée           0.0  12617.0        90.0        693.0
# 703                   Vienne           0.0  11585.0        55.0        396.0
# 704                   Vosges           0.0  36958.0        52.0       1573.0
# 705                    Yonne           0.0  25371.0       151.0       2357.0
# 706                 Yvelines           0.0  79640.0       905.0       5443.0
#
#            Date
# 0    2020-03-31
# ...
